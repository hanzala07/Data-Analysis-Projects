# %%
import numpy as np  #linear algebra
import pandas as pd #data preprocessing, csv files I/O

# %%
matches = pd.read_csv("matches.csv")
matches.info()
matches.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
#  17  umpire3          0 non-null      float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 81.3+ KB
#    id  season        city       date                  team1  \
# 0   1    2008   Bangalore  4/18/2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  4/19/2008    Chennai Super Kings
# 2   3    2008       Delhi  4/19/2008       Rajasthan Royals
# 3   4    2008      Mumbai  4/20/2008         Mumbai Indians
# 4   5    2008     Kolkata  4/20/2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# 1  normal           0          Chennai Super Kings           33
# 2  normal           0             Delhi Daredevils            0
# 3  normal           0  Royal Challengers Bangalore            0
# 4  normal           0        Kolkata Knight Riders            0
#
#    win_by_wickets player_of_match                                       venue  \
# 0               0     BB McCullum                       M Chinnaswamy Stadium
# 1               0      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2               9     MF Maharoof                            Feroz Shah Kotla
# 3               5      MV Boucher                            Wankhede Stadium
# 4               5       DJ Hussey                                Eden Gardens
#
#      umpire1         umpire2  umpire3
# 0  Asad Rauf     RE Koertzen      NaN
# 1  MR Benson      SL Shastri      NaN
# 2  Aleem Dar  GA Pratapkumar      NaN
# 3   SJ Davis       DJ Harper      NaN
# 4  BF Bowden     K Hariharan      NaN

# %%
matches.head(7)
# Out:
#    id  season        city       date                  team1  \
# 0   1    2008   Bangalore  4/18/2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  4/19/2008    Chennai Super Kings
# 2   3    2008       Delhi  4/19/2008       Rajasthan Royals
# 3   4    2008      Mumbai  4/20/2008         Mumbai Indians
# 4   5    2008     Kolkata  4/20/2008        Deccan Chargers
# 5   6    2008      Jaipur  4/21/2008        Kings XI Punjab
# 6   7    2008   Hyderabad  4/22/2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
# 5             Rajasthan Royals              Kings XI Punjab           bat
# 6             Delhi Daredevils              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# 1  normal           0          Chennai Super Kings           33
# 2  normal           0             Delhi Daredevils            0
# 3  normal           0  Royal Challengers Bangalore            0
# 4  normal           0        Kolkata Knight Riders            0
# 5  normal           0             Rajasthan Royals            0
# 6  normal           0             Delhi Daredevils            0
#
#    win_by_wickets player_of_match                                       venue  \
# 0               0     BB McCullum                       M Chinnaswamy Stadium
# 1               0      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2               9     MF Maharoof                            Feroz Shah Kotla
# 3               5      MV Boucher                            Wankhede Stadium
# 4               5       DJ Hussey                                Eden Gardens
# 5               6       SR Watson                      Sawai Mansingh Stadium
# 6               9        V Sehwag   Rajiv Gandhi International Stadium, Uppal
#
#      umpire1         umpire2  umpire3
# 0  Asad Rauf     RE Koertzen      NaN
# 1  MR Benson      SL Shastri      NaN
# 2  Aleem Dar  GA Pratapkumar      NaN
# 3   SJ Davis       DJ Harper      NaN
# 4  BF Bowden     K Hariharan      NaN
# 5  Aleem Dar       RB Tiffin      NaN
# 6  IL Howell       AM Saheba      NaN

# %%
matches[pd.isnull(matches['winner'])]
#find all the NaN values in winner column, so that we update this as draw
# Out:
#       id  season       city       date                        team1  \
# 241  242    2011      Delhi  5/21/2011             Delhi Daredevils
# 486  487    2015  Bangalore  4/29/2015  Royal Challengers Bangalore
# 511  512    2015  Bangalore  5/17/2015             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 241                Pune Warriors             Delhi Daredevils           bat
# 486             Rajasthan Royals             Rajasthan Royals         field
# 511  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 241  no result           0    NaN            0               0
# 486  no result           0    NaN            0               0
# 511  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 241             NaN       Feroz Shah Kotla        SS Hazare     RJ Tucker
# 486             NaN  M Chinnaswamy Stadium        JD Cloete     PG Pathak
# 511             NaN  M Chinnaswamy Stadium  HDPK Dharmasena  K Srinivasan
#
#      umpire3
# 241      NaN
# 486      NaN
# 511      NaN

# %%
matches['winner'].fillna('Draw', inplace=True)

# %%
matches.loc[241,'winner']
# Out:
# 'Draw'

# %%
matches['team1'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions'], dtype=object)

# %%
matches.replace(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
       'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
       'Royal Challengers Bangalore', 'Delhi Daredevils',
       'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
       'Rising Pune Supergiants', 'Gujarat Lions']
        ,['KKR','CSK','RR','MI','DC','KXIP','RCB','DD','KTK','PW','SRH','RPS','GL'],inplace=True)

matches.head()
# Out:
#    id  season        city       date team1 team2 toss_winner toss_decision  \
# 0   1    2008   Bangalore  4/18/2008   KKR   RCB         RCB         field
# 1   2    2008  Chandigarh  4/19/2008   CSK  KXIP         CSK           bat
# 2   3    2008       Delhi  4/19/2008    RR    DD          RR           bat
# 3   4    2008      Mumbai  4/20/2008    MI   RCB          MI           bat
# 4   5    2008     Kolkata  4/20/2008    DC   KKR          DC           bat
#
#    result  dl_applied winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0    KKR          140               0     BB McCullum
# 1  normal           0    CSK           33               0      MEK Hussey
# 2  normal           0     DD            0               9     MF Maharoof
# 3  normal           0    RCB            0               5      MV Boucher
# 4  normal           0    KKR            0               5       DJ Hussey
#
#                                         venue    umpire1         umpire2  \
# 0                       M Chinnaswamy Stadium  Asad Rauf     RE Koertzen
# 1  Punjab Cricket Association Stadium, Mohali  MR Benson      SL Shastri
# 2                            Feroz Shah Kotla  Aleem Dar  GA Pratapkumar
# 3                            Wankhede Stadium   SJ Davis       DJ Harper
# 4                                Eden Gardens  BF Bowden     K Hariharan
#
#    umpire3
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
encode = {'team1' : {'KKR':1,'CSK':2,'RR':3,'MI':4,'DC':5,'KXIP':6,'RCB':7,'DD':8,'KTK':9,'PW':10,'SRH':11,'RPS':12,'GL':13},
          'team2' : {'KKR':1,'CSK':2,'RR':3,'MI':4,'DC':5,'KXIP':6,'RCB':7,'DD':8,'KTK':9,'PW':10,'SRH':11,'RPS':12,'GL':13},
          'toss_winner' :{'KKR':1,'CSK':2,'RR':3,'MI':4,'DC':5,'KXIP':6,'RCB':7,'DD':8,'KTK':9,'PW':10,'SRH':11,'RPS':12,'GL':13},
          'winner' : {'KKR':1,'CSK':2,'RR':3,'MI':4,'DC':5,'KXIP':6,'RCB':7,'DD':8,'KTK':9,'PW':10,'SRH':11,'RPS':12,'GL':13,'Draw':14}}

matches.replace(encode,inplace=True)
matches.head()
# Out:
#    id  season        city       date  team1  team2  toss_winner toss_decision  \
# 0   1    2008   Bangalore  4/18/2008      1      7            7         field
# 1   2    2008  Chandigarh  4/19/2008      2      6            2           bat
# 2   3    2008       Delhi  4/19/2008      3      8            3           bat
# 3   4    2008      Mumbai  4/20/2008      4      7            4           bat
# 4   5    2008     Kolkata  4/20/2008      5      1            5           bat
#
#    result  dl_applied  winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0       1          140               0     BB McCullum
# 1  normal           0       2           33               0      MEK Hussey
# 2  normal           0       8            0               9     MF Maharoof
# 3  normal           0       7            0               5      MV Boucher
# 4  normal           0       1            0               5       DJ Hussey
#
#                                         venue    umpire1         umpire2  \
# 0                       M Chinnaswamy Stadium  Asad Rauf     RE Koertzen
# 1  Punjab Cricket Association Stadium, Mohali  MR Benson      SL Shastri
# 2                            Feroz Shah Kotla  Aleem Dar  GA Pratapkumar
# 3                            Wankhede Stadium   SJ Davis       DJ Harper
# 4                                Eden Gardens  BF Bowden     K Hariharan
#
#    umpire3
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Find cities which are null?
matches[pd.isnull(matches['city'])]
# Out:
#       id  season city       date  team1  team2  toss_winner toss_decision  \
# 402  403    2014  NaN  4/19/2014      4      7            7         field
# 403  404    2014  NaN  4/19/2014      1      8            1           bat
# 407  408    2014  NaN  4/23/2014      2      3            3         field
# 409  410    2014  NaN  4/25/2014     11      8           11           bat
# 410  411    2014  NaN  4/25/2014      4      2            4           bat
# 415  416    2014  NaN  4/28/2014      7      6            6         field
# 417  418    2014  NaN  4/30/2014     11      4            4         field
#
#      result  dl_applied  winner  win_by_runs  win_by_wickets player_of_match  \
# 402  normal           0       7            0               7        PA Patel
# 403  normal           0       8            0               4       JP Duminy
# 407  normal           0       2            7               0       RA Jadeja
# 409  normal           0      11            4               0        AJ Finch
# 410  normal           0       2            0               7       MM Sharma
# 415  normal           0       6            0               5  Sandeep Sharma
# 417  normal           0      11           15               0         B Kumar
#
#                                    venue          umpire1         umpire2  \
# 402  Dubai International Cricket Stadium        Aleem Dar    AK Chaudhary
# 403  Dubai International Cricket Stadium        Aleem Dar     VA Kulkarni
# 407  Dubai International Cricket Stadium  HDPK Dharmasena  RK Illingworth
# 409  Dubai International Cricket Stadium        M Erasmus          S Ravi
# 410  Dubai International Cricket Stadium        BF Bowden       M Erasmus
# 415  Dubai International Cricket Stadium        BF Bowden          S Ravi
# 417  Dubai International Cricket Stadium  HDPK Dharmasena       M Erasmus
#
#      umpire3
# 402      NaN
# 403      NaN
# 407      NaN
# 409      NaN
# 410      NaN
# 415      NaN
# 417      NaN

# %%
# remove any null values, winner has hence fill the null value in winner as draw
# city is also null, this mainly for dubai stadium. hence update the city as dubai
# Make sure to impute the data(cleaning and finding missing data), there is also other process
# to verify excepted value based on other resultants, for now by stadium, city is easily manually updated

matches['city'].fillna('Dubai',inplace=True)
matches.describe()
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             577 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    int64
#  5   team2            577 non-null    int64
#  6   toss_winner      577 non-null    int64
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           577 non-null    int64
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
#  17  umpire3          0 non-null      float64
# dtypes: float64(1), int64(9), object(8)
# memory usage: 81.3+ KB

# %%
# team_match_total = matches.groupby(["team1"]).size()+matches.groupby(["team2"]).size()
# print(team_match_total.get_value(1))

#xx = matches.groupby(["toss_winner"]).size()
#print(xx.get_value(1))

#yy = matches.groupby(["winner"]).size()
#print(yy.get_value(1))

# %%
# we maintain a dictionary for future reference mapping teams

dicval = encode['winner']
print(dicval['MI']) # key value
print(list(dicval.keys())[list(dicval.values()).index(4)]) #find key by value search
# Out:
# 4
# MI

# %%
matches = matches[['team1', 'team2','city','toss_decision','toss_winner','venue','winner']]
matches.head()
# Out:
#    team1  team2        city toss_decision  toss_winner  \
# 0      1      7   Bangalore         field            7
# 1      2      6  Chandigarh           bat            2
# 2      3      8       Delhi           bat            3
# 3      4      7      Mumbai           bat            4
# 4      5      1     Kolkata           bat            5
#
#                                         venue  winner
# 0                       M Chinnaswamy Stadium       1
# 1  Punjab Cricket Association Stadium, Mohali       2
# 2                            Feroz Shah Kotla       8
# 3                            Wankhede Stadium       7
# 4                                Eden Gardens       1

# %%
df = pd.DataFrame(matches)
df.describe()
# Out:
#             team1       team2  toss_winner      winner
# count  577.000000  577.000000   577.000000  577.000000
# mean     5.256499    5.433276     5.223570    5.135182
# std      3.073192    3.095607     3.073791    3.132340
# min      1.000000    1.000000     1.000000    1.000000
# 25%      3.000000    3.000000     3.000000    2.000000
# 50%      5.000000    6.000000     5.000000    4.000000
# 75%      7.000000    8.000000     7.000000    7.000000
# max     13.000000   13.000000    13.000000   14.000000
